# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import anderson
import seaborn as sns

# %%
#calling the data, solution 1

csv_path_s1v1 =  r"csv-data_traces/trace_s1v1_claw.csv"
csv_path_s1v2 =  r"csv-data_traces/trace_s1v2_claw.csv"
csv_path_s1v3 =  r"csv-data_traces/trace_s1v3_claw.csv"
csv_path_s1v4 =  r"csv-data_traces/trace_s1v4_claw.csv"
csv_path_s1v5 =  r"csv-data_traces/trace_s1v5_claw.csv"
csv_path_s1v6 =  r"csv-data_traces/trace_s1v6_claw.csv"
csv_path_s1v7 =  r"csv-data_traces/trace_s1v7_claw.csv"

df_s1v1 =  pd.read_csv(csv_path_s1v1)
df_s1v2 =  pd.read_csv(csv_path_s1v2)
df_s1v3 =  pd.read_csv(csv_path_s1v3)
df_s1v4 =  pd.read_csv(csv_path_s1v4)
df_s1v5 =  pd.read_csv(csv_path_s1v5)
df_s1v6 =  pd.read_csv(csv_path_s1v6)
df_s1v7 =  pd.read_csv(csv_path_s1v7)

df_s1v1 =  df_s1v1.sort_values("Frame")
df_s1v2 =  df_s1v2.sort_values("Frame")
df_s1v3 =  df_s1v3.sort_values("Frame")
df_s1v4 =  df_s1v4.sort_values("Frame")
df_s1v5 =  df_s1v5.sort_values("Frame")
df_s1v6 =  df_s1v6.sort_values("Frame")
df_s1v7 =  df_s1v7.sort_values("Frame")

# %%
#calling the data, solution 2

csv_path_s2v1 =  r"csv-data_traces/trace_s2v1_claw.csv"
csv_path_s2v2 =  r"csv-data_traces/trace_s2v2_claw.csv"
csv_path_s2v3 =  r"csv-data_traces/trace_s2v3_claw.csv"
csv_path_s2v4 =  r"csv-data_traces/trace_s2v4_claw.csv"
csv_path_s2v5 =  r"csv-data_traces/trace_s2v5_claw.csv"
csv_path_s2v6 =  r"csv-data_traces/trace_s2v6_claw.csv"
csv_path_s2v7 =  r"csv-data_traces/trace_s2v7_claw.csv"

df_s2v1 =  pd.read_csv(csv_path_s2v1)
df_s2v2 =  pd.read_csv(csv_path_s2v2)
df_s2v3 =  pd.read_csv(csv_path_s2v3)
df_s2v4 =  pd.read_csv(csv_path_s2v4)
df_s2v5 =  pd.read_csv(csv_path_s2v5)
df_s2v6 =  pd.read_csv(csv_path_s2v6)
df_s2v7 =  pd.read_csv(csv_path_s2v7)

df_s2v1 =  df_s2v1.sort_values("Frame")
df_s2v2 =  df_s2v2.sort_values("Frame")
df_s2v3 =  df_s2v3.sort_values("Frame")
df_s2v4 =  df_s2v4.sort_values("Frame")
df_s2v5 =  df_s2v5.sort_values("Frame")
df_s2v6 =  df_s2v6.sort_values("Frame")
df_s2v7 =  df_s2v7.sort_values("Frame")

# %%
#calling the data, solution 3

csv_path_s3v1 =  r"csv-data_traces/trace_s3v1_claw.csv"
csv_path_s3v2 =  r"csv-data_traces/trace_s3v2_claw.csv"
csv_path_s3v3 =  r"csv-data_traces/trace_s3v3_claw.csv"
csv_path_s3v4 =  r"csv-data_traces/trace_s3v4_claw.csv"
csv_path_s3v5 =  r"csv-data_traces/trace_s3v5_claw.csv"
csv_path_s3v6 =  r"csv-data_traces/trace_s3v6_claw.csv"
csv_path_s3v7 =  r"csv-data_traces/trace_s3v7_claw.csv"
csv_path_s3v8 =  r"csv-data_traces/trace_s3v8_claw.csv"

df_s3v1 =  pd.read_csv(csv_path_s3v1)
df_s3v2 =  pd.read_csv(csv_path_s3v2)
df_s3v3 =  pd.read_csv(csv_path_s3v3)
df_s3v4 =  pd.read_csv(csv_path_s3v4)
df_s3v5 =  pd.read_csv(csv_path_s3v5)
df_s3v6 =  pd.read_csv(csv_path_s3v6)
df_s3v7 =  pd.read_csv(csv_path_s3v7)
df_s3v8 =  pd.read_csv(csv_path_s3v8)

df_s3v1 =  df_s3v1.sort_values("Frame")
df_s3v2 =  df_s3v2.sort_values("Frame")
df_s3v3 =  df_s3v3.sort_values("Frame")
df_s3v4 =  df_s3v4.sort_values("Frame")
df_s3v5 =  df_s3v5.sort_values("Frame")
df_s3v6 =  df_s3v6.sort_values("Frame")
df_s3v7 =  df_s3v7.sort_values("Frame")
df_s3v8 =  df_s3v8.sort_values("Frame")

# %%
#calling the data, solution 4

csv_path_s4v1 =  r"csv-data_traces/trace_s4v1_claw.csv"
csv_path_s4v2 =  r"csv-data_traces/trace_s4v2_claw.csv"
csv_path_s4v3 =  r"csv-data_traces/trace_s4v3_claw.csv"
csv_path_s4v4 =  r"csv-data_traces/trace_s4v4_claw.csv"
csv_path_s4v5 =  r"csv-data_traces/trace_s4v5_claw.csv"
csv_path_s4v6 =  r"csv-data_traces/trace_s4v6_claw.csv"
csv_path_s4v7 =  r"csv-data_traces/trace_s4v7_claw.csv"

df_s4v1 =  pd.read_csv(csv_path_s4v1)
df_s4v2 =  pd.read_csv(csv_path_s4v2)
df_s4v3 =  pd.read_csv(csv_path_s4v3)
df_s4v4 =  pd.read_csv(csv_path_s4v4)
df_s4v5 =  pd.read_csv(csv_path_s4v5)
df_s4v6 =  pd.read_csv(csv_path_s4v6)
df_s4v7 =  pd.read_csv(csv_path_s4v7)

df_s4v1 =  df_s4v1.sort_values("Frame")
df_s4v2 =  df_s4v2.sort_values("Frame")
df_s4v3 =  df_s4v3.sort_values("Frame")
df_s4v4 =  df_s4v4.sort_values("Frame")
df_s4v5 =  df_s4v5.sort_values("Frame")
df_s4v6 =  df_s4v6.sort_values("Frame")
df_s4v7 =  df_s4v7.sort_values("Frame")

# %%
#calling the data, solution 5

csv_path_s5v1 =  r"csv-data_traces/trace_s5v1_claw.csv"
csv_path_s5v2 =  r"csv-data_traces/trace_s5v2_claw.csv"
csv_path_s5v3 =  r"csv-data_traces/trace_s5v3_claw.csv"
csv_path_s5v4 =  r"csv-data_traces/trace_s5v4_claw.csv"
csv_path_s5v5 =  r"csv-data_traces/trace_s5v5_claw.csv"
csv_path_s5v6 =  r"csv-data_traces/trace_s5v6_claw.csv"
csv_path_s5v7 =  r"csv-data_traces/trace_s5v7_claw.csv"

df_s5v1 =  pd.read_csv(csv_path_s5v1)
df_s5v2 =  pd.read_csv(csv_path_s5v2)
df_s5v3 =  pd.read_csv(csv_path_s5v3)
df_s5v4 =  pd.read_csv(csv_path_s5v4)
df_s5v5 =  pd.read_csv(csv_path_s5v5)
df_s5v6 =  pd.read_csv(csv_path_s5v6)
df_s5v7 =  pd.read_csv(csv_path_s5v7)

df_s5v1 =  df_s5v1.sort_values("Frame")
df_s5v2 =  df_s5v2.sort_values("Frame")
df_s5v3 =  df_s5v3.sort_values("Frame")
df_s5v4 =  df_s5v4.sort_values("Frame")
df_s5v5 =  df_s5v5.sort_values("Frame")
df_s5v6 =  df_s5v6.sort_values("Frame")
df_s5v7 =  df_s5v7.sort_values("Frame")

# %%
#calling the data, solution 6

csv_path_s6v1 =  r"csv-data_traces/trace_s6v1_claw.csv"
csv_path_s6v2 =  r"csv-data_traces/trace_s6v2_claw.csv"
csv_path_s6v3 =  r"csv-data_traces/trace_s6v3_claw.csv"
csv_path_s6v4 =  r"csv-data_traces/trace_s6v4_claw.csv"
csv_path_s6v5 =  r"csv-data_traces/trace_s6v5_claw.csv"
csv_path_s6v6 =  r"csv-data_traces/trace_s6v6_claw.csv"
csv_path_s6v7 =  r"csv-data_traces/trace_s6v7_claw.csv"
csv_path_s6v8 =  r"csv-data_traces/trace_s6v8_claw.csv"
csv_path_s6v9 =  r"csv-data_traces/trace_s6v9_claw.csv"

df_s6v1 =  pd.read_csv(csv_path_s6v1)
df_s6v2 =  pd.read_csv(csv_path_s6v2)
df_s6v3 =  pd.read_csv(csv_path_s6v3)
df_s6v4 =  pd.read_csv(csv_path_s6v4)
df_s6v5 =  pd.read_csv(csv_path_s6v5)
df_s6v6 =  pd.read_csv(csv_path_s6v6)
df_s6v7 =  pd.read_csv(csv_path_s6v7)
df_s6v8 =  pd.read_csv(csv_path_s6v8)
df_s6v9 =  pd.read_csv(csv_path_s6v9)

df_s6v1 =  df_s6v1.sort_values("Frame")
df_s6v2 =  df_s6v2.sort_values("Frame")
df_s6v3 =  df_s6v3.sort_values("Frame")
df_s6v4 =  df_s6v4.sort_values("Frame")
df_s6v5 =  df_s6v5.sort_values("Frame")
df_s6v6 =  df_s6v6.sort_values("Frame")
df_s6v7 =  df_s6v7.sort_values("Frame")
df_s6v8 =  df_s6v8.sort_values("Frame")
df_s6v9 =  df_s6v9.sort_values("Frame")

# %%
#calling the data, solution 7

csv_path_s7v1 =  r"csv-data_traces/trace_s7v1_claw.csv"
csv_path_s7v2 =  r"csv-data_traces/trace_s7v2_claw.csv"
csv_path_s7v3 =  r"csv-data_traces/trace_s7v3_claw.csv"
csv_path_s7v4 =  r"csv-data_traces/trace_s7v4_claw.csv"
csv_path_s7v5 =  r"csv-data_traces/trace_s7v5_claw.csv"
csv_path_s7v6 =  r"csv-data_traces/trace_s7v6_claw.csv"
csv_path_s7v7 =  r"csv-data_traces/trace_s7v7_claw.csv"
csv_path_s7v8 =  r"csv-data_traces/trace_s7v8_claw.csv"
csv_path_s7v9 =  r"csv-data_traces/trace_s7v9_claw.csv"
csv_path_s7v10 = r"csv-data_traces/trace_s7v10_claw.csv"
csv_path_s7v11 = r"csv-data_traces/trace_s7v11_claw.csv"
csv_path_s7v12 = r"csv-data_traces/trace_s7v12_claw.csv"

df_s7v1 =  pd.read_csv(csv_path_s7v1)
df_s7v2 =  pd.read_csv(csv_path_s7v2)
df_s7v3 =  pd.read_csv(csv_path_s7v3)
df_s7v4 =  pd.read_csv(csv_path_s7v4)
df_s7v5 =  pd.read_csv(csv_path_s7v5)
df_s7v6 =  pd.read_csv(csv_path_s7v6)
df_s7v7 =  pd.read_csv(csv_path_s7v7)
df_s7v8 =  pd.read_csv(csv_path_s7v8)
df_s7v9 =  pd.read_csv(csv_path_s7v9)
df_s7v10 = pd.read_csv(csv_path_s7v10)
df_s7v11 = pd.read_csv(csv_path_s7v11)
df_s7v12 = pd.read_csv(csv_path_s7v12)

df_s7v1 =  df_s7v1.sort_values("Frame")
df_s7v2 =  df_s7v2.sort_values("Frame")
df_s7v3 =  df_s7v3.sort_values("Frame")
df_s7v4 =  df_s7v4.sort_values("Frame")
df_s7v5 =  df_s7v5.sort_values("Frame")
df_s7v6 =  df_s7v6.sort_values("Frame")
df_s7v7 =  df_s7v7.sort_values("Frame")
df_s7v8 =  df_s7v8.sort_values("Frame")
df_s7v9 =  df_s7v9.sort_values("Frame")
df_s7v10 = df_s7v10.sort_values("Frame")
df_s7v11 = df_s7v11.sort_values("Frame")
df_s7v12 = df_s7v12.sort_values("Frame")

# %%
plt.plot((df_s7v1["Centro_X"]-np.mean(df_s7v1["Centro_X"])))

# %%
#dfs1 = [df_s1v1, df_s1v2, df_s1v3, df_s1v4, df_s1v5, df_s1v6, df_s1v7]
dfs1 = [df_s1v1, df_s1v2, df_s1v4, df_s1v5, df_s1v7]

#dfs2 = [df_s2v1, df_s2v2, df_s2v3, df_s2v4, df_s2v5, df_s2v6, df_s2v7]
dfs2 = [df_s2v1, df_s2v2, df_s2v4, df_s2v5, df_s2v6]

#dfs3 = [df_s3v1, df_s3v2, df_s3v3, df_s3v4, df_s3v5, df_s3v6, df_s3v7, df_s3v8]
dfs3 = [df_s3v1, df_s3v2, df_s3v3, df_s3v5, df_s3v6]

#dfs4 = [df_s4v1, df_s4v2, df_s4v3, df_s4v4, df_s4v5, df_s4v6, df_s4v7]
dfs4 = [df_s4v1, df_s4v2, df_s4v3, df_s4v6, df_s4v7]

#dfs5 = [df_s5v1, df_s5v2, df_s5v3, df_s5v4, df_s5v5, df_s5v6, df_s5v7]
dfs5 = [df_s5v2, df_s5v3, df_s5v4, df_s5v5, df_s5v6]

#dfs6 = [df_s6v1, df_s6v2, df_s6v3, df_s6v4, df_s6v5, df_s6v6, df_s6v7, df_s6v8, df_s6v9]
dfs6 = [df_s6v1, df_s6v3, df_s6v4, df_s6v6, df_s6v8]

#dfs7 = [df_s7v1, df_s7v2, df_s7v4, df_s7v5, df_s7v6, df_s7v7, df_s7v8, df_s7v9, df_s7v11, df_s7v12]
dfs7 = [df_s7v1, df_s7v2, df_s7v4, df_s7v5, df_s7v6]

# %%
x = pd.concat([(df["Centro_X"] - np.mean(df["Centro_X"]))*0.053 for df in dfs1])
y = pd.concat([(df["Centro_Y"] - np.mean(df["Centro_Y"]))*0.053 for df in dfs1])

#nbins1 = 18
#nbins2 = 25
nbins7 = 16

nbins=nbins7

fontSize = 22
fig, ax = plt.subplots(1, 2, figsize=(9, 4.1), sharey=False)

sns.histplot(x, bins=nbins, stat="density", ax=ax[0], color='skyblue')
ax[0].set_xlabel(r'$x$ [$\mu$m]',fontsize=fontSize)
ax[0].set_xlim(-0.7, 0.7)
ax[0].set_ylim(0, 7)

sns.histplot(y, bins=nbins, stat="density", ax=ax[1], color='skyblue')
ax[1].set_xlabel(r'$y$ [$\mu$m]',fontsize=fontSize)
ax[1].set_xlim(-0.7, 0.7)
ax[1].set_ylim(0, 7)

ax[0].tick_params(axis='both',labelsize=20)
ax[1].tick_params(axis='both',labelsize=20)

ax[0].set_ylabel(r'', fontsize=fontSize)
ax[1].set_ylabel(r'', fontsize=fontSize)

plt.tight_layout()
#plt.savefig("dist_s1.pdf", format="pdf", dpi=2000, bbox_inches="tight")
plt.show()
